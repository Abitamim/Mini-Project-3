# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
values = pd.read_csv("data.csv")

# %%
values["Time"] = np.linspace(0, 20, len(values))

# %%
values = values[:100]
plt.plot(values["Time"], values["Left Motor"])
